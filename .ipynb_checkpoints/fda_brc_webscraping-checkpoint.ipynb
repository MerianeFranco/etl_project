# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd
from datetime import date

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/90.0.4430.24/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\meria\.wdm\drivers\chromedriver\win32\90.0.4430.24]

# %%
#Create a function to scrape the data from the FDA Website
#We will get company name and last FDA inspection date based on the FEI number that it is part of the URL
    
def fda_info(fei):
    browser = Browser('chrome', **executable_path, headless=False)
    url = 'https://datadashboard.fda.gov/ora/firmprofile.htm?FEIs='+str(fei)
    browser.visit(url)
    time.sleep(10) #time < 9 seconds does not work
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    browser.quit()
    header_results = soup.find_all('h3')
    inspection_results = soup.find_all('span',class_="ng-binding ng-scope")
    address_results = soup.find_all('div',class_="col-xs-12 col-sm-12 col-md-4 col-lg-4 firm_address")
    
#store the info that you are looking for in variables
#FEI number, Company name and last inspection date by FDA
    last_inspection = inspection_results[1].text
    fei = header_results[0].text
    company = header_results[1].text
    address = address_results[0].text

#return the info from the finction
    return fei,company,last_inspection,address

# %%
#get the csv file information and convert it to a pandas dataframe
supplier_list = pd.read_csv('supplier_info.csv')
supplier_list.head()
# Out:
#    supplier_id      fei      brc
# 0            0  2244191  1851425
# 1            1  2412472  1657536
# 2            2  1310769  6950748
# 3            3  1046390        n
# 4            4  1819038  5316427

# %%
#Collect the fei number from the csv file and creat a loop to get the web information using the funtion fda_info;
supplier_fei = supplier_list['fei'].tolist()
fdaweb = []
for x in supplier_fei:
    try:    
        fdaweb.append(fda_info(x))
    except:
        pass
#print (fdaweb)

# %%
#Conver the FDA data into a Pandas DataFrame
df = pd.DataFrame(fdaweb)
FEI_df = df.rename(columns = {0:"fei",1:"Company Name_FDA",2:"Inspection Date_FDA",3:"Company Address_FDA"})
FEI_df
# Out:
#            fei                    Company Name_FDA Inspection Date_FDA  \
# 0      2244191                     AAK Foodservice          08/15/2019
# 1      2412472              Acme Smoked Fish Corp.          03/12/2020
# 2      1310769            ADM Milling Company Inc.          01/29/2021
# 3      1046390                 ADM Milling Company          06/16/2016
# 4      1819038                 ADM Milling Company          11/02/2017
# ..         ...                                 ...                 ...
# 91     1711390  The Amalgamated Sugar Company, LLC          05/06/2013
# 92     3080721  The Amalgamated Sugar Company, LLC          09/29/2009
# 93  3004253338      The Amalgamated Sugar Co., LLC          01/18/2013
# 94  3003968007     Strictly Organic Coffee Company          02/22/2017
# 95  3010581458                      Made in Nature          10/17/2014
#
#                                   Company Address_FDA
# 0   \nFirm Address\n465 Hillside Ave\nHillside, NJ...
# 1   \nFirm Address\n30 Gem St\nBrooklyn, New York ...
# 2   \nFirm Address\n250 Ganson St\nBuffalo, NY 142...
# 3   \nFirm Address\n430 Central Ave Ne\nCleveland,...
# 4   \nFirm Address\n854 Bethel Ave\nBeech Grove, I...
# ..                                                ...
# 91  \nFirm Address\n701 N Main St\nBrighton, CO 80...
# 92  \nFirm Address\n2600 NE Columbia Blvd\nPortlan...
# 93  \nFirm Address\n99 Factory Rd\nEaton, CO 80615...
# 94  \nFirm Address\n6 SW Bond St\nBend, OR 97702-3...
# 95  \nFirm Address\n5555 E Lamona Ave Ste 102\nFre...
#
# [96 rows x 4 columns]

# %%
#Cleaning the address data in the address column
FEI_df['Company Address_FDA'] = FEI_df['Company Address_FDA'].str.replace('\nFirm Address\n','')
FEI_df['Company Address_FDA'] = FEI_df['Company Address_FDA'].str.replace('\n',' ')
FEI_df.head()
# Out:
#        fei          Company Name_FDA Inspection Date_FDA  \
# 0  2244191           AAK Foodservice          08/15/2019
# 1  2412472    Acme Smoked Fish Corp.          03/12/2020
# 2  1310769  ADM Milling Company Inc.          01/29/2021
# 3  1046390       ADM Milling Company          06/16/2016
# 4  1819038       ADM Milling Company          11/02/2017
#
#                                  Company Address_FDA
# 0  465 Hillside Ave Hillside, NJ 07205-1121 Unite...
# 1  30 Gem St Brooklyn, New York 11222 United States
# 2  250 Ganson St Buffalo, NY 14203-3048 United St...
# 3  430 Central Ave Ne Cleveland, TN 37311-5590 Un...
# 4  854 Bethel Ave Beech Grove, IN 46107-1142 Unit...

# %%
# Save the Pandas Data Frame in an excel file
file_name = 'FEI_webdata.xlsx'
FEI_df.to_excel(file_name)

# %%
#Create a function to scrape the data from the BRC Website
#We will get company name, address, certification grade and expiration date of the certificate

def brc_info(sitecode):
    browser = Browser('chrome', **executable_path, headless=False)
    url = 'https://directory.brcgs.com/site/'+str(sitecode)
    
    browser.visit(url)
    time.sleep(1) #time for the website do not think I am a robot
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    browser.quit()
        
    results = soup.find_all('h1')
    new_results = soup.find_all('li',class_="EntryPair_entryPair__1zyEr InfoBox_entryPair__35IoY")

    # Company name and address were in a fixed location 
    company = results[0].text
    address = new_results[1].text
    
    # Certification Grade, and Certificate exp date were stored in different index number, among the companies
    #In order to overcome this issue and keep using pandas, a text.partition was used to  
    for x in range(0,len(new_results)):
        spl_word="Grade"
        res = new_results[x].text.partition(spl_word)[2]
        if res != '':
            grade = res
            
    for x in range(0,len(new_results)):
        spl_word="Expiry Date"
        res = new_results[x].text.partition(spl_word)[2]
        if res != '':
            exp_date = res    
        
    return sitecode, company, address, grade, exp_date

# %%
#Collect the brc number from the csv file and creat a loop to get the web information using the funtion brc_info;
supplier_brccode = supplier_list['brc'].tolist()
brcweb = []
for x in supplier_brccode:
    if x != 'n':# when the supplier does not have a brc certification, it is listed as n and we don't need to use the function.
        try:
            brcweb.append(brc_info(x))
        except:
            pass
#print(brcweb)

# %%
#Conver the BRC data into a Pandas DataFrame
dfbrc = pd.DataFrame(brcweb)
BRC_df = dfbrc.rename(columns = {0:"brc",1:"BRC Company Name",2:"BRC Address", 3:"BRC Grade", 4: "BRC Expiration"})
BRC_df.head()
# Out:
#        brc               BRC Company Name  \
# 0  1851425                AAK Foodservice
# 1  1657536          Acme Smoked Fish Corp
# 2  6950748  ADM Milling Company - Buffalo
# 3  5316427      ADM Milling - Beech Grove
# 4  1982979        ADM Milling - Charlotte
#
#                                          BRC Address BRC Grade BRC Expiration
# 0  Address465 Hillside Avenue, Hillside, New Jers...         C     2021-09-27
# 1  Address30 Gem Street, Brooklyn, New York, New ...        AA     2022-04-06
# 2  Address250 Ganson St., Buffalo, New York, 1420...         A     2022-04-02
# 3  Address854 Bethel Ave, Beech Grove, Indiana, 4...        AA     2021-11-16
# 4  Address620 W 10th St, Charlotte, North Carolin...        AA     2021-12-21

# %%
#Clean the address data in the address column
BRC_df['BRC Address'] = BRC_df['BRC Address'].str.replace('Address','')
BRC_df.head()
# Out:
#        brc               BRC Company Name  \
# 0  1851425                AAK Foodservice
# 1  1657536          Acme Smoked Fish Corp
# 2  6950748  ADM Milling Company - Buffalo
# 3  5316427      ADM Milling - Beech Grove
# 4  1982979        ADM Milling - Charlotte
#
#                                          BRC Address BRC Grade BRC Expiration
# 0  465 Hillside Avenue, Hillside, New Jersey, 072...         C     2021-09-27
# 1  30 Gem Street, Brooklyn, New York, New York, 1...        AA     2022-04-06
# 2  250 Ganson St., Buffalo, New York, 14203, UNIT...         A     2022-04-02
# 3  854 Bethel Ave, Beech Grove, Indiana, 46107, U...        AA     2021-11-16
# 4  620 W 10th St, Charlotte, North Carolina, 2820...        AA     2021-12-21

# %%
# Save the Pandas Data Frame in an excel file
file = 'BRC_webdata.xlsx'
BRC_df.to_excel(file)

# %%
#convert columns to string before merging
BRC_df['brc']=BRC_df['brc'].apply(str)
FEI_df['fei']=FEI_df['fei'].apply(str)
supplier_list['fei']=supplier_list['fei'].apply(str)
supplier_list['brc']=supplier_list['brc'].apply(str)

# %%
#Merge the data

FEI_supplier = FEI_df.merge(supplier_list, how='outer', on ='fei')
FEI_BRC_supplier = FEI_supplier.merge(BRC_df, how='outer', on ='brc')

# %%
FEI_BRC_supplier.head()
# Out:
#        fei          Company Name_FDA Inspection Date_FDA  \
# 0  2244191           AAK Foodservice          08/15/2019
# 1  2412472    Acme Smoked Fish Corp.          03/12/2020
# 2  1310769  ADM Milling Company Inc.          01/29/2021
# 3  1046390       ADM Milling Company          06/16/2016
# 4  1416339           ADM Milling Co.          06/11/2019
#
#                                  Company Address_FDA  supplier_id      brc  \
# 0  465 Hillside Ave Hillside, NJ 07205-1121 Unite...            0  1851425
# 1  30 Gem St Brooklyn, New York 11222 United States             1  1657536
# 2  250 Ganson St Buffalo, NY 14203-3048 United St...            2  6950748
# 3  430 Central Ave Ne Cleveland, TN 37311-5590 Un...            3        n
# 4  1300 W Carroll Ave Chicago, IL 60607-1118 Unit...            5        n
#
#                 BRC Company Name  \
# 0                AAK Foodservice
# 1          Acme Smoked Fish Corp
# 2  ADM Milling Company - Buffalo
# 3                            NaN
# 4                            NaN
#
#                                          BRC Address BRC Grade BRC Expiration
# 0  465 Hillside Avenue, Hillside, New Jersey, 072...         C     2021-09-27
# 1  30 Gem Street, Brooklyn, New York, New York, 1...        AA     2022-04-06
# 2  250 Ganson St., Buffalo, New York, 14203, UNIT...         A     2022-04-02
# 3                                                NaN       NaN            NaN
# 4                                                NaN       NaN            NaN

# %%
#Convert FDA inspection date to date format
for i in range (len(FEI_BRC_supplier)) :
    
    try:
        FEI_BRC_supplier.loc[i, "Inspection Date_FDA"]= pd.to_datetime(FEI_BRC_supplier.loc[i,"Inspection Date_FDA"])
    except:
         FEI_BRC_supplier.loc[i, "Inspection Date_FDA"] = "Not available"
FEI_BRC_supplier.head()
# Out:
#        fei          Company Name_FDA  Inspection Date_FDA  \
# 0  2244191           AAK Foodservice  2019-08-15 00:00:00
# 1  2412472    Acme Smoked Fish Corp.  2020-03-12 00:00:00
# 2  1310769  ADM Milling Company Inc.  2021-01-29 00:00:00
# 3  1046390       ADM Milling Company  2016-06-16 00:00:00
# 4  1416339           ADM Milling Co.  2019-06-11 00:00:00
#
#                                  Company Address_FDA  supplier_id      brc  \
# 0  465 Hillside Ave Hillside, NJ 07205-1121 Unite...            0  1851425
# 1  30 Gem St Brooklyn, New York 11222 United States             1  1657536
# 2  250 Ganson St Buffalo, NY 14203-3048 United St...            2  6950748
# 3  430 Central Ave Ne Cleveland, TN 37311-5590 Un...            3        n
# 4  1300 W Carroll Ave Chicago, IL 60607-1118 Unit...            5        n
#
#                 BRC Company Name  \
# 0                AAK Foodservice
# 1          Acme Smoked Fish Corp
# 2  ADM Milling Company - Buffalo
# 3                            NaN
# 4                            NaN
#
#                                          BRC Address BRC Grade BRC Expiration
# 0  465 Hillside Avenue, Hillside, New Jersey, 072...         C     2021-09-27
# 1  30 Gem Street, Brooklyn, New York, New York, 1...        AA     2022-04-06
# 2  250 Ganson St., Buffalo, New York, 14203, UNIT...         A     2022-04-02
# 3                                                NaN       NaN            NaN
# 4                                                NaN       NaN            NaN

# %%
#Apply supplier scoring 
# FDA Score - Based on the last FDA inspection:
# - If FDA inspection it is over 3 years - 50 points
# - If FDA inspection it is over 2 years - 20 points
# - If FDA inspection it is less than 2 years - 0 points
# - If no FDA inspection - 100 points

# BRC Score - Based on BRC audit grade:
# - If AA+ or AA - 0 points
# - If A or B - 10 points
# - If C or D - 30 points
# - If no BRC certification or certificate expired - 100 points

# Final score will be the sum of FDA and BRC scores and can vary from 0 to 200.

# %%
# Insert new columns for the scores
FEI_BRC_supplier["brc_score"]=""
FEI_BRC_supplier["fda_score"]=""
FEI_BRC_supplier["Final Score"]=""

# %%
#insert column to hold today's date
FEI_BRC_supplier["Today"]=""

# %%
for i in range(len(FEI_BRC_supplier)):
    FEI_BRC_supplier.loc[i,"Today"]=pd.to_datetime('today')

# %%
FEI_BRC_supplier.head()
# Out:
#        fei          Company Name_FDA  Inspection Date_FDA  \
# 0  2244191           AAK Foodservice  2019-08-15 00:00:00
# 1  2412472    Acme Smoked Fish Corp.  2020-03-12 00:00:00
# 2  1310769  ADM Milling Company Inc.  2021-01-29 00:00:00
# 3  1046390       ADM Milling Company  2016-06-16 00:00:00
# 4  1416339           ADM Milling Co.  2019-06-11 00:00:00
#
#                                  Company Address_FDA  supplier_id      brc  \
# 0  465 Hillside Ave Hillside, NJ 07205-1121 Unite...            0  1851425
# 1  30 Gem St Brooklyn, New York 11222 United States             1  1657536
# 2  250 Ganson St Buffalo, NY 14203-3048 United St...            2  6950748
# 3  430 Central Ave Ne Cleveland, TN 37311-5590 Un...            3        n
# 4  1300 W Carroll Ave Chicago, IL 60607-1118 Unit...            5        n
#
#                 BRC Company Name  \
# 0                AAK Foodservice
# 1          Acme Smoked Fish Corp
# 2  ADM Milling Company - Buffalo
# 3                            NaN
# 4                            NaN
#
#                                          BRC Address BRC Grade BRC Expiration  \
# 0  465 Hillside Avenue, Hillside, New Jersey, 072...         C     2021-09-27
# 1  30 Gem Street, Brooklyn, New York, New York, 1...        AA     2022-04-06
# 2  250 Ganson St., Buffalo, New York, 14203, UNIT...         A     2022-04-02
# 3                                                NaN       NaN            NaN
# 4                                                NaN       NaN            NaN
#
#   brc_score fda_score Final Score                       Today
# 0                                  2021-04-25 17:41:56.004124
# 1                                  2021-04-25 17:41:56.006519
# 2                                  2021-04-25 17:41:56.007018
# 3                                  2021-04-25 17:41:56.007018
# 4                                  2021-04-25 17:41:56.007018

# %%
#calculate BRC score:
# BRC Score - Based on BRC audit grade:
# If AA+ or AA = 0; A = 5; B=10; C=20; D=30
# If no BRC certification or certificate expired = 100 points

for i in range(len(FEI_BRC_supplier)):
    if FEI_BRC_supplier.loc[i,"BRC Grade"] == 'AA+':
        FEI_BRC_supplier.loc[i,"brc_score"]=0
    elif FEI_BRC_supplier.loc[i,"BRC Grade"] == 'AA':
        FEI_BRC_supplier.loc[i,"brc_score"]=0
    elif FEI_BRC_supplier.loc[i,"BRC Grade"] == 'A':
        FEI_BRC_supplier.loc[i,"brc_score"]=5
    elif FEI_BRC_supplier.loc[i,"BRC Grade"] == 'B':
        FEI_BRC_supplier.loc[i,"brc_score"]=10
    elif FEI_BRC_supplier.loc[i,"BRC Grade"] == str('C'):
        FEI_BRC_supplier.loc[i,"brc_score"]=20
    elif FEI_BRC_supplier.loc[i,"BRC Grade"] =='D':
        FEI_BRC_supplier.loc[i,"brc_score"]=30
    else:
        FEI_BRC_supplier.loc[i,"brc_score"]=100

# %%
FEI_BRC_supplier.head()
# Out:
#        fei          Company Name_FDA  Inspection Date_FDA  \
# 0  2244191           AAK Foodservice  2019-08-15 00:00:00
# 1  2412472    Acme Smoked Fish Corp.  2020-03-12 00:00:00
# 2  1310769  ADM Milling Company Inc.  2021-01-29 00:00:00
# 3  1046390       ADM Milling Company  2016-06-16 00:00:00
# 4  1416339           ADM Milling Co.  2019-06-11 00:00:00
#
#                                  Company Address_FDA  supplier_id      brc  \
# 0  465 Hillside Ave Hillside, NJ 07205-1121 Unite...            0  1851425
# 1  30 Gem St Brooklyn, New York 11222 United States             1  1657536
# 2  250 Ganson St Buffalo, NY 14203-3048 United St...            2  6950748
# 3  430 Central Ave Ne Cleveland, TN 37311-5590 Un...            3        n
# 4  1300 W Carroll Ave Chicago, IL 60607-1118 Unit...            5        n
#
#                 BRC Company Name  \
# 0                AAK Foodservice
# 1          Acme Smoked Fish Corp
# 2  ADM Milling Company - Buffalo
# 3                            NaN
# 4                            NaN
#
#                                          BRC Address BRC Grade BRC Expiration  \
# 0  465 Hillside Avenue, Hillside, New Jersey, 072...         C     2021-09-27
# 1  30 Gem Street, Brooklyn, New York, New York, 1...        AA     2022-04-06
# 2  250 Ganson St., Buffalo, New York, 14203, UNIT...         A     2022-04-02
# 3                                                NaN       NaN            NaN
# 4                                                NaN       NaN            NaN
#
#   brc_score fda_score Final Score                       Today
# 0        20                        2021-04-25 17:17:27.142885
# 1         0                        2021-04-25 17:17:27.143885
# 2         5                        2021-04-25 17:17:27.143885
# 3       100                        2021-04-25 17:17:27.144896
# 4       100                        2021-04-25 17:17:27.144896

# %%
test_df = FEI_BRC_supplier
test_df.head()
# Out:
#        fei          Company Name_FDA  Inspection Date_FDA  \
# 0  2244191           AAK Foodservice  2019-08-15 00:00:00
# 1  2412472    Acme Smoked Fish Corp.  2020-03-12 00:00:00
# 2  1310769  ADM Milling Company Inc.  2021-01-29 00:00:00
# 3  1046390       ADM Milling Company  2016-06-16 00:00:00
# 4  1416339           ADM Milling Co.  2019-06-11 00:00:00
#
#                                  Company Address_FDA  supplier_id      brc  \
# 0  465 Hillside Ave Hillside, NJ 07205-1121 Unite...            0  1851425
# 1  30 Gem St Brooklyn, New York 11222 United States             1  1657536
# 2  250 Ganson St Buffalo, NY 14203-3048 United St...            2  6950748
# 3  430 Central Ave Ne Cleveland, TN 37311-5590 Un...            3        n
# 4  1300 W Carroll Ave Chicago, IL 60607-1118 Unit...            5        n
#
#                 BRC Company Name  \
# 0                AAK Foodservice
# 1          Acme Smoked Fish Corp
# 2  ADM Milling Company - Buffalo
# 3                            NaN
# 4                            NaN
#
#                                          BRC Address BRC Grade BRC Expiration  \
# 0  465 Hillside Avenue, Hillside, New Jersey, 072...         C     2021-09-27
# 1  30 Gem Street, Brooklyn, New York, New York, 1...        AA     2022-04-06
# 2  250 Ganson St., Buffalo, New York, 14203, UNIT...         A     2022-04-02
# 3                                                NaN       NaN            NaN
# 4                                                NaN       NaN            NaN
#
#   brc_score fda_score Final Score                       Today
# 0        20                        2021-04-25 17:41:56.004124
# 1         0                        2021-04-25 17:41:56.006519
# 2         5                        2021-04-25 17:41:56.007018
# 3       100                        2021-04-25 17:41:56.007018
# 4       100                        2021-04-25 17:41:56.007018

# %%
# FDA Score - Based on the last FDA inspection:
# - If FDA inspection it is over 3 years (1095 days) - 50 points
# - If FDA inspection it is over 2 years (730 days) - 20 points
# - If FDA inspection it is less than 2 years (730 days) - 5 points
# - If no FDA inspection - 100 points


for i in range(len(test_df)):
    
    try:
        if int((test_df.loc[i,"Today"] - test_df.loc[i,"Inspection Date_FDA"]).days)>1095:
            test_df.loc[i,"fda_score"]=50
        elif int((test_df.loc[i,"Today"] - test_df.loc[i,"Inspection Date_FDA"]).days)>730:
            test_df.loc[i,"fda_score"]=20
        elif int((test_df.loc[i,"Today"] - test_df.loc[i,"Inspection Date_FDA"]).days)<=730:
            test_df.loc[i,"fda_score"]=5
    except:
        test_df.loc[i,"fda_score"]=100

# %%
test_df
# Out:
#            fei                    Company Name_FDA  Inspection Date_FDA  \
# 0      2244191                     AAK Foodservice  2019-08-15 00:00:00
# 1      2412472              Acme Smoked Fish Corp.  2020-03-12 00:00:00
# 2      1310769            ADM Milling Company Inc.  2021-01-29 00:00:00
# 3      1046390                 ADM Milling Company  2016-06-16 00:00:00
# 4      1416339                     ADM Milling Co.  2019-06-11 00:00:00
# ..         ...                                 ...                  ...
# 95     3080721  The Amalgamated Sugar Company, LLC  2009-09-29 00:00:00
# 96  3010581458                      Made in Nature  2014-10-17 00:00:00
# 97  3004252238                                 NaN                  NaT
# 98  3009327165                                 NaN                  NaT
# 99  3004804821                                 NaN                  NaT
#
#                                   Company Address_FDA  supplier_id      brc  \
# 0   465 Hillside Ave Hillside, NJ 07205-1121 Unite...            0  1851425
# 1   30 Gem St Brooklyn, New York 11222 United States             1  1657536
# 2   250 Ganson St Buffalo, NY 14203-3048 United St...            2  6950748
# 3   430 Central Ave Ne Cleveland, TN 37311-5590 Un...            3        n
# 4   1300 W Carroll Ave Chicago, IL 60607-1118 Unit...            5        n
# ..                                                ...          ...      ...
# 95  2600 NE Columbia Blvd Portland, OR 97211-2056 ...           97  1587775
# 96  5555 E Lamona Ave Ste 102 Fresno, CA 93727-229...          100  3937598
# 97                                                NaN           43  6665737
# 98                                                NaN           51  1020958
# 99                                                NaN           78  3604346
#
#                        BRC Company Name  \
# 0                       AAK Foodservice
# 1                 Acme Smoked Fish Corp
# 2         ADM Milling Company - Buffalo
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 95   The Amalgamated Sugar Company LLC
# 96                   Made In Nature LLC
# 97             Cereal Ingredients, Inc.
# 98  Cuisine Innovations Unlimited, LLC.
# 99                        Innophos Inc.
#
#                                           BRC Address BRC Grade  \
# 0   465 Hillside Avenue, Hillside, New Jersey, 072...         C
# 1   30 Gem Street, Brooklyn, New York, New York, 1...        AA
# 2   250 Ganson St., Buffalo, New York, 14203, UNIT...         A
# 3                                                 NaN       NaN
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 95  2600 N.E. Columbia Blvd, Portland, Oregon, 972...        AA
# 96  5555 E. Lamona Ave. Ste 102, Fresno, Californi...        AA
# 97  4720 South 13th Street, Leavenworth, Kansas, 6...         A
# 98  180 Lehigh Ave. Lakewood, New Jersey, New Jers...         A
# 99  10810 Highway 75, Geismar, Louisiana, 70734, U...        AA
#
#    BRC Expiration brc_score fda_score Final Score                       Today
# 0      2021-09-27        20         5              2021-04-25 17:41:56.004124
# 1      2022-04-06         0         5              2021-04-25 17:41:56.006519
# 2      2022-04-02         5         5              2021-04-25 17:41:56.007018
# 3             NaN       100        50              2021-04-25 17:41:56.007018
# 4             NaN       100         5              2021-04-25 17:41:56.007018
# ..            ...       ...       ...         ...                         ...
# 95     2021-11-11         0        50              2021-04-25 17:41:56.027575
# 96     2021-12-02         0        50              2021-04-25 17:41:56.027575
# 97     2022-03-25         5       100              2021-04-25 17:41:56.028566
# 98     2021-09-14         5       100              2021-04-25 17:41:56.028566
# 99     2022-04-26         0       100              2021-04-25 17:41:56.028566
#
# [100 rows x 14 columns]

# %%
# Add bonth scores to get the supplier final score:
for i in range(len(test_df)):
    test_df.loc[i,"Final Score"] = test_df.loc[i,"fda_score"]+test_df.loc[i,"brc_score"]

# %%
test_df
# Out:
#            fei                    Company Name_FDA  Inspection Date_FDA  \
# 0      2244191                     AAK Foodservice  2019-08-15 00:00:00
# 1      2412472              Acme Smoked Fish Corp.  2020-03-12 00:00:00
# 2      1310769            ADM Milling Company Inc.  2021-01-29 00:00:00
# 3      1046390                 ADM Milling Company  2016-06-16 00:00:00
# 4      1416339                     ADM Milling Co.  2019-06-11 00:00:00
# ..         ...                                 ...                  ...
# 95     3080721  The Amalgamated Sugar Company, LLC  2009-09-29 00:00:00
# 96  3010581458                      Made in Nature  2014-10-17 00:00:00
# 97  3004252238                                 NaN                  NaT
# 98  3009327165                                 NaN                  NaT
# 99  3004804821                                 NaN                  NaT
#
#                                   Company Address_FDA  supplier_id      brc  \
# 0   465 Hillside Ave Hillside, NJ 07205-1121 Unite...            0  1851425
# 1   30 Gem St Brooklyn, New York 11222 United States             1  1657536
# 2   250 Ganson St Buffalo, NY 14203-3048 United St...            2  6950748
# 3   430 Central Ave Ne Cleveland, TN 37311-5590 Un...            3        n
# 4   1300 W Carroll Ave Chicago, IL 60607-1118 Unit...            5        n
# ..                                                ...          ...      ...
# 95  2600 NE Columbia Blvd Portland, OR 97211-2056 ...           97  1587775
# 96  5555 E Lamona Ave Ste 102 Fresno, CA 93727-229...          100  3937598
# 97                                                NaN           43  6665737
# 98                                                NaN           51  1020958
# 99                                                NaN           78  3604346
#
#                        BRC Company Name  \
# 0                       AAK Foodservice
# 1                 Acme Smoked Fish Corp
# 2         ADM Milling Company - Buffalo
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 95   The Amalgamated Sugar Company LLC
# 96                   Made In Nature LLC
# 97             Cereal Ingredients, Inc.
# 98  Cuisine Innovations Unlimited, LLC.
# 99                        Innophos Inc.
#
#                                           BRC Address BRC Grade  \
# 0   465 Hillside Avenue, Hillside, New Jersey, 072...         C
# 1   30 Gem Street, Brooklyn, New York, New York, 1...        AA
# 2   250 Ganson St., Buffalo, New York, 14203, UNIT...         A
# 3                                                 NaN       NaN
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 95  2600 N.E. Columbia Blvd, Portland, Oregon, 972...        AA
# 96  5555 E. Lamona Ave. Ste 102, Fresno, Californi...        AA
# 97  4720 South 13th Street, Leavenworth, Kansas, 6...         A
# 98  180 Lehigh Ave. Lakewood, New Jersey, New Jers...         A
# 99  10810 Highway 75, Geismar, Louisiana, 70734, U...        AA
#
#    BRC Expiration brc_score fda_score Final Score                       Today
# 0      2021-09-27        20         5          25  2021-04-25 17:41:56.004124
# 1      2022-04-06         0         5           5  2021-04-25 17:41:56.006519
# 2      2022-04-02         5         5          10  2021-04-25 17:41:56.007018
# 3             NaN       100        50         150  2021-04-25 17:41:56.007018
# 4             NaN       100         5         105  2021-04-25 17:41:56.007018
# ..            ...       ...       ...         ...                         ...
# 95     2021-11-11         0        50          50  2021-04-25 17:41:56.027575
# 96     2021-12-02         0        50          50  2021-04-25 17:41:56.027575
# 97     2022-03-25         5       100         105  2021-04-25 17:41:56.028566
# 98     2021-09-14         5       100         105  2021-04-25 17:41:56.028566
# 99     2022-04-26         0       100         100  2021-04-25 17:41:56.028566
#
# [100 rows x 14 columns]
